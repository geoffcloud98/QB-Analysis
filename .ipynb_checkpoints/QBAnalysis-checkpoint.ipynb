# %% [markdown]
# <h1>Predicting Future Quarterback Performance</h1>
# This project will analyze a dataset of quarterback statistics from <b>2014 - 2016</b>. A head coach in the NFL is evaluating potential quarterbacks for a trade and wants to predict how effective each quarterback will be in their passing game. The coach is particularly interested in predicting <b>future Passing Yards</b> based on the quarterback's performance, such as <b>Passes Attempted</b>, <b>Completion Percentage</b>, <b>Passing Yards</b>, and <b>TD Passes</b>.
# By using these stats, the coach can get an estimate of which quarterbacks are likely to consistently gain more yardage, helping inform trade decisions.

# %%
import pandas as pd

# %%
qb_data = pd.read_csv('Game_Logs_Quarterback.csv')
qb_data
# Out:
#                     Player Id              Name Position  Year  \
# 0      jaredzabransky/2495791  Zabransky, Jared      NaN  2007
# 1      jaredzabransky/2495791  Zabransky, Jared      NaN  2007
# 2      jaredzabransky/2495791  Zabransky, Jared      NaN  2007
# 3      jaredzabransky/2495791  Zabransky, Jared      NaN  2007
# 4          billdemory/2512778      Demory, Bill      NaN  1974
# ...                       ...               ...      ...   ...
# 40242     steveramsey/2523725     Ramsey, Steve      NaN  1971
# 40243     steveramsey/2523725     Ramsey, Steve      NaN  1971
# 40244     steveramsey/2523725     Ramsey, Steve      NaN  1971
# 40245     steveramsey/2523725     Ramsey, Steve      NaN  1970
# 40246     steveramsey/2523725     Ramsey, Steve      NaN  1970
#
#                Season  Week Game Date Home or Away Opponent Outcome  ... Ints  \
# 0           Preseason     1     08/11         Home      CHI       L  ...   --
# ...

# %% [markdown]
# <h1>Reshaping the data</h1>
# There are a decent amount of columns in this dataset that will not be used. First thing we can do is reduce the DataFrame size with only the features we are interested in (i.e. <b>Passes Attempted</b>, <b>Completion Percentage</b>, <b>Passing Yards</b>, and <b>TD Passes</b>) from 2014 - 2016.

# %%
qb_data = qb_data[(qb_data.Year >= 2014) & (qb_data.Year <= 2016) & (qb_data.Season == 'Regular Season')]
qb_data = qb_data[['Player Id', 'Name', 'Year', 'Week', 'Passes Attempted', 'Completion Percentage', 'Passing Yards', 'TD Passes']]
qb_data
# Out:
#                    Player Id             Name  Year  Week Passes Attempted  \
# 34         tomsavage/2543640      Savage, Tom  2016     1               --
# 35         tomsavage/2543640      Savage, Tom  2016     2               --
# 36         tomsavage/2543640      Savage, Tom  2016     3               --
# 37         tomsavage/2543640      Savage, Tom  2016     4               --
# 38         tomsavage/2543640      Savage, Tom  2016     5               --
# ...                      ...              ...   ...   ...              ...
# 40108  brockosweiler/2533436  Osweiler, Brock  2014    13               --
# 40109  brockosweiler/2533436  Osweiler, Brock  2014    14               --
# 40110  brockosweiler/2533436  Osweiler, Brock  2014    15                2
# 40111  brockosweiler/2533436  Osweiler, Brock  2014    16               --
# 40112  brockosweiler/2533436  Osweiler, Brock  2014    17                2
#
#       Completion Percentage Passing Yards TD Passes
# ...

# %% [markdown]
# <h1>Cleaning the data</h1>

# %%
print(qb_data['Passes Attempted'].dtype)
print(qb_data['Completion Percentage'].dtype)
print(qb_data['Passing Yards'].dtype)
print(qb_data['TD Passes'].dtype)
# Out:
# object
# object
# object
# object

# %% [markdown]
# There are missing values in the data which could indicate that a quarterback did not play in the game for that current week. Those "empty" values are actually '--' and are read as a string value. We will need to replace these with 0 and change the column types.

# %%
qb_data = qb_data.replace('--', 0)

qb_data = qb_data.astype({'Passes Attempted': 'int64',
    'Completion Percentage': 'float64',
    'Passing Yards': 'int64',
    'TD Passes': 'int64'
})

# %% [markdown]
# Before predictions are made, we need to see if the correlation between <b>Passing Yards</b> and the columns we are using for our prediction model are strong. But first we need a subset of the numerical columns.

# %%
numeric_data = qb_data.select_dtypes(include=[float,int])
numeric_data.corr()['Passing Yards']
# Out:
# Year                    -0.017291
# Week                    -0.031591
# Passes Attempted         0.957149
# Completion Percentage    0.876302
# Passing Yards            1.000000
# TD Passes                0.784558
# Name: Passing Yards, dtype: float64

# %% [markdown]
# We can see a strong correlation between <b>Passes Attempted</b>, <b>Completion percentage</b>, <b>TD Passes</b>, and <b>Passing Yards</b>. To see a visual representation of Passes attempted and Passing Yards, we will use seaborn.

# %%
import seaborn as sns
sns.lmplot(x='Passes Attempted', y='Passing Yards', data=qb_data, fit_reg=True, ci=None)

# %% [markdown]
# Based on this visual alone, we could predict that the more passing attempts a quarterback has, the higher their passing yards will be by the end of the game.
#
# <h2>Training the model</h2>
# We will split the data into training and testing sets for our machine learning model. Our training set size will be set to quarterback statistics from 2014 and 2015 while our testing set will be the quarterback statistics from 2016.

# %%
#Set up predictors and target variables
train = qb_data[(qb_data.Year == 2014) | (qb_data.Year == 2015)].copy() #This will be the input to the machine learning model
test = qb_data[qb_data.Year == 2016].copy() #This is what the model will try to predict

# %% [markdown]
# Now that we have the subsets for our model, it's time to start training it. From sklearn, we'll be using the <b>Linear Regression</b> model in order to make our predictions. We will make our predictions based off of <b>Passes Attempted</b>, <b>Completion percentage</b>, <b>TD Passes</b> and our target will be <b>Passing Yards</b>

# %%
from sklearn.linear_model import LinearRegression
reg_model = LinearRegression()
predictors = ['Passes Attempted', 'Completion Percentage', 'TD Passes']
target = 'Passing Yards'
reg_model.fit(train[predictors], train[target])
# Out:
# LinearRegression()

# %%
predictions = reg_model.predict(test[predictors])
test['Predictions'] = predictions
test.head(25)
# Out:
#                Player Id          Name  Year  Week  Passes Attempted  \
# 34     tomsavage/2543640   Savage, Tom  2016     1                 0
# 35     tomsavage/2543640   Savage, Tom  2016     2                 0
# 36     tomsavage/2543640   Savage, Tom  2016     3                 0
# 37     tomsavage/2543640   Savage, Tom  2016     4                 0
# 38     tomsavage/2543640   Savage, Tom  2016     5                 0
# 39     tomsavage/2543640   Savage, Tom  2016     6                 0
# 40     tomsavage/2543640   Savage, Tom  2016     7                 0
# 41     tomsavage/2543640   Savage, Tom  2016     8                 0
# 42     tomsavage/2543640   Savage, Tom  2016    10                 0
# 43     tomsavage/2543640   Savage, Tom  2016    11                 0
# 44     tomsavage/2543640   Savage, Tom  2016    12                 0
# 45     tomsavage/2543640   Savage, Tom  2016    13                 0
# 46     tomsavage/2543640   Savage, Tom  2016    14                 0
# ...

# %% [markdown]
# After generating the predictions and storing them in a new column named <i>Predictions</i>, within the testing dataset, some predicted passing yard values are negative and not rounded. We will manually adjust these issues and sort the data by Name, Year, and Week.

# %%
test.loc[test.Predictions < 0, 'Predictions'] = 0
test.Predictions = test.Predictions.round()
test = test.sort_values(by=['Name', 'Year', 'Week'], ascending=[False, True, True])
test.head(25)
# Out:
#                    Player Id             Name  Year  Week  Passes Attempted  \
# 2526       t.j.yates/2508123      Yates, T.J.  2016    15                 0
# 2527       t.j.yates/2508123      Yates, T.J.  2016    16                 0
# 2528       t.j.yates/2508123      Yates, T.J.  2016    17                 0
# 33839  jameiswinston/2552033  Winston, Jameis  2016     1                32
# 33840  jameiswinston/2552033  Winston, Jameis  2016     2                52
# 33841  jameiswinston/2552033  Winston, Jameis  2016     3                58
# 33842  jameiswinston/2552033  Winston, Jameis  2016     4                35
# 33843  jameiswinston/2552033  Winston, Jameis  2016     5                30
# 33844  jameiswinston/2552033  Winston, Jameis  2016     7                30
# 33845  jameiswinston/2552033  Winston, Jameis  2016     8                32
# 33846  jameiswinston/2552033  Winston, Jameis  2016     9                37
# ...

# %% [markdown]
# <h2>Error Metric</h2>
#
# Now that we have our predictions, we can evaluate our linear regression model's performance by calculating the <b>mean absolute error</b> (MAE). This is useful because, if we choose to experiment with different machine learning models, we can compare their MAE values and select the model with the lower MAE, indicating its predictions are closer to the actual targets.

# %%
from sklearn.metrics import mean_absolute_error
error = mean_absolute_error(test[target], test.Predictions)
error
# Out:
# 16.59504132231405

# %% [markdown]
# Our <b>mean absolute error</b> suggests that our predictions will be off by approximately 16.6 yards from the actual passing yard values on average.

# %%
qb_data.describe()
# Out:
#               Year         Week  Passes Attempted  Completion Percentage  \
# count  3421.000000  3421.000000       3421.000000            3421.000000
# mean   2015.039754     9.087109         14.838059              29.162087
# std       0.816245     5.036709         17.869477              32.470039
# min    2014.000000     1.000000          0.000000               0.000000
# 25%    2014.000000     5.000000          0.000000               0.000000
# 50%    2015.000000     9.000000          0.000000               0.000000
# 75%    2016.000000    14.000000         32.000000              62.500000
# max    2016.000000    17.000000         65.000000             100.000000
#
#        Passing Yards    TD Passes
# count    3421.000000  3421.000000
# mean      106.980123     0.664718
# std       131.661999     1.082885
# min        -3.000000     0.000000
# 25%         0.000000     0.000000
# 50%         0.000000     0.000000
# 75%       231.000000     1.000000
# ...

# %% [markdown]
# <h2>Conclusion</h2>
# In this analysis, we developed a linear regression model to predict quarterback passing yards using data from 2014 to 2016. By using features such as <b>Passes Attempted</b>, <b>Completion percentage</b>, and <b>TD Passes</b>, the model scored a mean absolute error (MAE) of approximately 16.6 passing yards, indicating a high level of prediction accuracy. Even though the model produced reasonable predictions in many cases, certain outliers, such as negative passing yards, highlight areas for improvement. A way to tackle this issue would be to remove rows from our predictor columns where the values are 0 or less than 0.
#
# Future work on this could include experimenting with more complex models to see which one performs better, and ensuring the data is thoroughly cleaned to avoid unrealistic predictions. By applying this model to future seasons, coaches or analysts could use it to evaluate player performance or make decisions on trades.
